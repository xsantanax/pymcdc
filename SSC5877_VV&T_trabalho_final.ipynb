# %% [markdown]
# # SSC5877 - Verificação, Validação e Teste de Software

# %% [markdown]
# ## Trabalho final - Desafio

# %% [markdown]
# ### Conceitos

# %% [markdown]
# #### O que é um ano bissexto?

# %% [markdown]
# Um ano bissexto é aquele que possui 366 dias ao invés de 365, com o dia extra sendo 29 de fevereiro. De acordo com as regras do calendário gregoriano (em vigor desde 1752), um ano é bissexto se:
#
# *   For divisível por 4
#
# *   Exceto se for divisível por 100
#
# *   A menos que também seja divisível por 400
#
# Além disso, anos anteriores a 1752 seguem uma lógica simplificada: são bissextos se forem divisíveis por 4.

# %% [markdown]
# #### O que é MC/DC?

# %% [markdown]
# MC/DC (Modified Condition/Decision Coverage) é um critério de teste que garante que:
#
# *   Cada condição atômica em uma decisão (ex: a and b) foi avaliada como True e False;
#
# *   Cada condição afeta isoladamente o resultado final da decisão.

# %% [markdown]
# ### Funções

# %% [markdown]
# #### Monitoramento

# %%
log_execucao = []

def monitorar(condicao_str, contexto):
    try:
        resultado = eval(condicao_str, {}, contexto)
        log_execucao.append((condicao_str, resultado))
        return resultado
    except Exception as e:
        log_execucao.append((condicao_str, f"Erro: {e}"))
        return False

# %% [markdown]
# #### Bissexto

# %%
codigo_eh_bissexto = '''
def eh_bissexto(ano: int) -> bool:
    if ano < 1 or ano > 9999:
        raise ValueError("Ano inválido: deve estar entre 1 e 9999.")

    if ano <= 1752:
        return ano % 4 == 0

    if ano % 400 == 0:
        return True
    if ano % 100 == 0:
        return False
    return ano % 4 == 0
'''

# %%
def eh_bissexto(ano: int) -> bool:
    contexto = {"ano": ano}

    if monitorar("ano < 1 or ano > 9999", contexto):
        raise ValueError("Ano inválido: deve estar entre 1 e 9999.")

    if monitorar("ano <= 1752", contexto):
        return monitorar("ano % 4 == 0", contexto)

    if monitorar("ano % 400 == 0", contexto):
        return True
    if monitorar("ano % 100 == 0", contexto):
        return False
    return monitorar("ano % 4 == 0", contexto)

# %% [markdown]
# #### Extração de decisões

# %%
import ast

def extrair_decisoes(codigo: str):
    arvore = ast.parse(codigo)
    decisoes = []

    class VisitanteDecisao(ast.NodeVisitor):
        def visit_If(self, node):
            decisoes.append(ast.unparse(node.test))
            self.generic_visit(node)

    VisitanteDecisao().visit(arvore)
    return decisoes

decisoes = extrair_decisoes(codigo_eh_bissexto)
for i, d in enumerate(decisoes, 1):
    print(f"Decisão {i}: {d}")
# Out:
# Decisão 1: ano < 1 or ano > 9999
# Decisão 2: ano <= 1752
# Decisão 3: ano % 400 == 0
# Decisão 4: ano % 100 == 0

# %% [markdown]
# #### Geração de combinações MC/DC

# %%
import itertools

def gerar_mcdc(decisao):
    operadores_logicos = ["and", "or"]
    for operador in operadores_logicos:
        if operador in decisao:
            termos = [t.strip(" ()") for t in decisao.split(operador)]
            combinacoes = list(itertools.product([True, False], repeat=len(termos)))
            validas = []

            for i, c1 in enumerate(combinacoes):
                for j, c2 in enumerate(combinacoes):
                    if i >= j:
                        continue
                    difs = [k for k in range(len(c1)) if c1[k] != c2[k]]
                    if len(difs) == 1:
                        r1 = eval(f" {operador} ".join(str(v) for v in c1))
                        r2 = eval(f" {operador} ".join(str(v) for v in c2))
                        if r1 != r2:
                            validas.append((c1, r1))
                            validas.append((c2, r2))

            unicos = []
            for entrada in validas:
                if entrada not in unicos:
                    unicos.append(entrada)
            return termos, unicos

    return [decisao], [((True,), True), ((False,), False)]

for decisao in decisoes:
    termos, entradas = gerar_mcdc(decisao)
    print(f"Decisão: {decisao}")
    print("Combinações a validar (entrada -> saída):")
    for entrada, resultado in entradas:
        print(f"  {entrada} -> {resultado}")
    print()
# Out:
# Decisão: ano < 1 or ano > 9999
# Combinações a validar (entrada -> saída):
#   (True, False) -> True
#   (False, False) -> False
#   (False, True) -> True
#
# Decisão: ano <= 1752
# Combinações a validar (entrada -> saída):
#   (True,) -> True
#   (False,) -> False
#
# Decisão: ano % 400 == 0
# Combinações a validar (entrada -> saída):
#   (True,) -> True
#   (False,) -> False
#
# Decisão: ano % 100 == 0
# Combinações a validar (entrada -> saída):
#   (True,) -> True
#   (False,) -> False

# %% [markdown]
# #### Validação das combinações

# %%
def avaliar_entrada(ano, termos, operador):
    valores = [eval(t, {}, {"ano": ano}) for t in termos]
    if operador:
        resultado = eval(f" {operador} ".join(str(v) for v in valores))
    else:
        resultado = valores[0]
    return tuple(valores), resultado

def extrair_termos_operador(decisao):
    if " and " in decisao:
        return [t.strip() for t in decisao.split("and")], "and"
    elif " or " in decisao:
        return [t.strip() for t in decisao.split("or")], "or"
    else:
        return [decisao.strip()], None

def verificar_cobertura_mcdc_real(decisoes, anos):
    print("Verificação da cobertura MC/DC com base nos anos testados:\n")

    for decisao in decisoes:
        termos, entradas_esperadas = gerar_mcdc(decisao)
        termos_completos, operador = extrair_termos_operador(decisao)

        entradas_reais = set()
        for ano in anos:
            try:
                valores, resultado = avaliar_entrada(ano, termos_completos, operador)
                entradas_reais.add((valores, resultado))
            except Exception:
                continue

        total = len(entradas_esperadas)
        cobertas = 0
        faltando = []

        for entrada, saida in entradas_esperadas:
            if (entrada, saida) in entradas_reais:
                cobertas += 1
            else:
                faltando.append((entrada, saida))

        print(f"Decisão: {decisao}")
        print("Combinações necessárias:")
        for e, r in entradas_esperadas:
            print(f"  {e} -> {r}")
        print(f"Cobertura atingida: {cobertas}/{total}")

        if cobertas == total:
            print("Cobertura MC/DC completa\n")
        else:
            print("Cobertura MC/DC incompleta")
            print("Faltando as combinações:")
            for e, r in faltando:
                print(f"  {e} -> {r}")
            print()

# %% [markdown]
# #### Função de execução

# %%
log_execucao = []

def executar_mcdc(anos):
    cobertura_decisao = {}

    for ano in anos:
        log_execucao.clear()
        try:
            resultado = eh_bissexto(ano)
            print(f"Ano {ano}: {'Bissexto' if resultado else 'Não bissexto'}")
        except ValueError as e:
            print(f"Ano {ano}: Erro - {e}")

        print("Condições avaliadas:")
        for cond, val in log_execucao:
            print(f"  {cond} => {val}")
            cobertura_decisao.setdefault(cond, set()).add(val)

        print("-" * 40)

    return cobertura_decisao

# %% [markdown]
# ### Testes

# %% [markdown]
# #### Testes estáticos

# %%
anos = [-1, 1600, 1700, 1752, 1800, 1900, 2000, 2020, 2023, 10000]

cobertura = executar_mcdc(anos)

print("Anos testados:")
print(anos)

print("-" * 40)

print("\nResumo da Cobertura:")

for cond, valores in cobertura.items():
    print(f"'{cond}': coberto {valores}")
# Out:
# Ano -1: Erro - Ano inválido: deve estar entre 1 e 9999.
# Condições avaliadas:
#   ano < 1 or ano > 9999 => True
# ----------------------------------------
# Ano 1600: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => True
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 1700: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => True
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 1752: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => True
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 1800: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => True
# ----------------------------------------
# Ano 1900: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => True
# ----------------------------------------
# Ano 2000: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => True
# ----------------------------------------
# Ano 2020: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 2023: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 10000: Erro - Ano inválido: deve estar entre 1 e 9999.
# Condições avaliadas:
#   ano < 1 or ano > 9999 => True
# ----------------------------------------
# Anos testados:
# [-1, 1600, 1700, 1752, 1800, 1900, 2000, 2020, 2023, 10000]
# ----------------------------------------
#
# Resumo da Cobertura:
# 'ano < 1 or ano > 9999': coberto {False, True}
# 'ano <= 1752': coberto {False, True}
# 'ano % 4 == 0': coberto {False, True}
# 'ano % 400 == 0': coberto {False, True}
# 'ano % 100 == 0': coberto {False, True}

# %%
verificar_cobertura_mcdc_real(decisoes, anos)
# Out:
# Verificação da cobertura MC/DC com base nos anos testados:
#
# Decisão: ano < 1 or ano > 9999
# Combinações necessárias:
#   (True, False) -> True
#   (False, False) -> False
#   (False, True) -> True
# Cobertura atingida: 3/3
# Cobertura MC/DC completa
#
# Decisão: ano <= 1752
# Combinações necessárias:
#   (True,) -> True
#   (False,) -> False
# Cobertura atingida: 2/2
# Cobertura MC/DC completa
#
# Decisão: ano % 400 == 0
# Combinações necessárias:
#   (True,) -> True
#   (False,) -> False
# Cobertura atingida: 2/2
# Cobertura MC/DC completa
#
# Decisão: ano % 100 == 0
# Combinações necessárias:
#   (True,) -> True
#   (False,) -> False
# Cobertura atingida: 2/2
# Cobertura MC/DC completa

# %% [markdown]
# #### Testes aleatórios

# %%
import random

log_execucao = []

anos = [random.randint(1, 9999) for _ in range(100)]

cobertura = executar_mcdc(anos)

print("Anos testados:")
print(anos)

print("-" * 40)

print("\nResumo:")

for cond, valores in cobertura.items():
    print(f"'{cond}': coberto {valores}")
# Out:
# Ano 7845: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 620: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => True
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 5470: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 4559: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 9341: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 5916: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 5938: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 4720: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 9395: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 6660: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 3165: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 9159: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 6217: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 6270: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 7307: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 8434: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 6689: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 1911: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 5693: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 3910: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 450: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => True
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 5251: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 139: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => True
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 3087: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 8443: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 4799: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 4833: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 9721: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 1427: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => True
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 1695: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => True
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 9870: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 5812: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 1826: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 6339: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 741: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => True
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 8784: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 4050: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 6391: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 7124: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 6098: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 9181: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 23: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => True
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 9470: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 5213: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 5214: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 5139: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 8709: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 1224: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => True
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 8398: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 8170: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 6949: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 5758: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 3587: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 6246: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 6516: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 535: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => True
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 1820: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 7732: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 7718: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 868: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => True
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 1428: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => True
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 1734: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => True
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 6188: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 8195: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 2251: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 7672: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 7851: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 5554: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 8025: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 5378: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 5191: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 6150: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 7010: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 2131: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 3999: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 5266: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 5921: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 700: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => True
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 8716: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 9649: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 2218: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 7793: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 6025: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 8601: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 9873: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 7905: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 659: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => True
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 61: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => True
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 9027: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 2696: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 6071: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 8816: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 3229: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 8398: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 1326: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => True
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 8374: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 6792: Bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => True
# ----------------------------------------
# Ano 3071: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 7526: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Ano 2705: Não bissexto
# Condições avaliadas:
#   ano < 1 or ano > 9999 => False
#   ano <= 1752 => False
#   ano % 400 == 0 => False
#   ano % 100 == 0 => False
#   ano % 4 == 0 => False
# ----------------------------------------
# Anos testados:
# [7845, 620, 5470, 4559, 9341, 5916, 5938, 4720, 9395, 6660, 3165, 9159, 6217, 6270, 7307, 8434, 6689, 1911, 5693, 3910, 450, 5251, 139, 3087, 8443, 4799, 4833, 9721, 1427, 1695, 9870, 5812, 1826, 6339, 741, 8784, 4050, 6391, 7124, 6098, 9181, 23, 9470, 5213, 5214, 5139, 8709, 1224, 8398, 8170, 6949, 5758, 3587, 6246, 6516, 535, 1820, 7732, 7718, 868, 1428, 1734, 6188, 8195, 2251, 7672, 7851, 5554, 8025, 5378, 5191, 6150, 7010, 2131, 3999, 5266, 5921, 700, 8716, 9649, 2218, 7793, 6025, 8601, 9873, 7905, 659, 61, 9027, 2696, 6071, 8816, 3229, 8398, 1326, 8374, 6792, 3071, 7526, 2705]
# ----------------------------------------
#
# Resumo:
# 'ano < 1 or ano > 9999': coberto {False}
# 'ano <= 1752': coberto {False, True}
# 'ano % 400 == 0': coberto {False}
# 'ano % 100 == 0': coberto {False}
# 'ano % 4 == 0': coberto {False, True}

# %%
verificar_cobertura_mcdc_real(decisoes, anos)
# Out:
# Verificação da cobertura MC/DC com base nos anos testados:
#
# Decisão: ano < 1 or ano > 9999
# Combinações necessárias:
#   (True, False) -> True
#   (False, False) -> False
#   (False, True) -> True
# Cobertura atingida: 1/3
# Cobertura MC/DC incompleta
# Faltando as combinações:
#   (True, False) -> True
#   (False, True) -> True
#
# Decisão: ano <= 1752
# Combinações necessárias:
#   (True,) -> True
#   (False,) -> False
# Cobertura atingida: 2/2
# Cobertura MC/DC completa
#
# Decisão: ano % 400 == 0
# Combinações necessárias:
#   (True,) -> True
#   (False,) -> False
# Cobertura atingida: 1/2
# Cobertura MC/DC incompleta
# Faltando as combinações:
#   (True,) -> True
#
# Decisão: ano % 100 == 0
# Combinações necessárias:
#   (True,) -> True
#   (False,) -> False
# Cobertura atingida: 2/2
# Cobertura MC/DC completa

# %% [markdown]
# ### Conclusões

# %% [markdown]
# ***Adicionar as conclusões e as observações das implementações feitas***

# %% [markdown]
# # Implementação Alternativa

# %% [markdown]
# Autor: Caio
#
# Não tenho certeza se entendi o que era pra fazer, mas seguem os códigos do ano bissexto e teste MC/DC.

# %% [markdown]
# Bissexto

# %%
def eh_bissexto(ano: int) -> bool:
    if ano < 1 or ano > 9999:
        raise ValueError("O ano deve estar entre 1 e 9999.")
    if ano <= 1752:
        return ano % 4 == 0
    if ano % 400 == 0:
        return True
    if ano % 100 == 0:
        return False
    return ano % 4 == 0

# %% [markdown]
# Teste

# %%
import unittest
from main import eh_bissexto


class TestEhBissextoMCDC(unittest.TestCase):

    # --- Testes para a Decisão 1: if ano < 1 or ano > 9999 ---

    def test_decisao1_condicao_A_mostra_independencia(self):
        # Teste 1: ano = 0 (A=True, B=False) -> Gera exceção
        with self.assertRaises(ValueError, msg="Deveria lançar exceção para ano < 1"):
            eh_bissexto(0)

        # Teste 2: ano = 2000 (A=False, B=False) -> Não gera exceção
        try:
            eh_bissexto(2000)
        except ValueError:
            self.fail("Não deveria lançar exceção para ano=2000")

    def test_decisao1_condicao_B_mostra_independencia(self):
        # Teste 1: ano = 10000 (A=False, B=True) -> Gera exceção
        with self.assertRaises(ValueError, msg="Deveria lançar exceção para ano > 9999"):
            eh_bissexto(10000)

        # Teste 2: ano = 2000 (A=False, B=False) -> Não gera exceção
        try:
            eh_bissexto(2000)
        except ValueError:
            self.fail("Não deveria lançar exceção para ano=2000")

    # --- Testes para os caminhos de execução após a validação ---

    def test_caminho_juliano_nao_bissexto(self):
        # ano=1751: D2 (ano <= 1752) é True, D2a (ano % 4 == 0) é False.
        self.assertFalse(eh_bissexto(1751), "Falhou para ano juliano não bissexto (1751)")

    def test_caminho_juliano_bissexto(self):
        # ano=1752: D2 (ano <= 1752) é True, D2a (ano % 4 == 0) é True.
        self.assertTrue(eh_bissexto(1752), "Falhou para ano juliano bissexto (1752)")

    def test_caminho_gregoriano_div_por_100_nao_400(self):
        # ano=1900: D2(F), D3(F), D4(T) -> Retorna False.
        self.assertFalse(eh_bissexto(1900), "Falhou para ano secular não bissexto (1900)")

    def test_caminho_gregoriano_div_por_400(self):
        # ano=2000: D2(F), D3(T) -> Retorna True.
        self.assertTrue(eh_bissexto(2000), "Falhou para ano secular bissexto (2000)")

    def test_caminho_gregoriano_div_por_4(self):
        # ano=2024: D4(F), D5(T) -> Retorna True.
        self.assertTrue(eh_bissexto(2024), "Falhou para ano comum bissexto (2024)")

    def test_caminho_gregoriano_nao_bissexto(self):
        # ano=2025: D5(F) -> Retorna False.
        self.assertFalse(eh_bissexto(2025), "Falhou para ano não bissexto (2025)")


if __name__ == '__main__':
    unittest.main(verbosity=2)

# %% [markdown]
# Comando pra rodar a budega

# %%
python -m unittest -v test_mcdc_bissexto.py
